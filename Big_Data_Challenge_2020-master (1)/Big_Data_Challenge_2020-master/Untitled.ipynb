# %%
# Load Excel data from Table 5.6, sheet 'Annual'
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

ipi = pd.read_excel('hackathon_ipi3.xlsx')
ipi
# Out:
#     FREQUENCY  TIME_Y     Value  Unnamed: 3 FREQUENCY.1       TIME_M  \
# 0           A  1955.0  50.97925         NaN           M  1956.000000
# 1           A  1956.0  50.89896         NaN           M  1956.083333
# 2           A  1957.0  51.94263         NaN           M  1956.166667
# 3           A  1958.0  51.17995         NaN           M  1956.250000
# 4           A  1959.0  54.20419         NaN           M  1956.333333
# ..        ...     ...       ...         ...         ...          ...
# 769       NaN     NaN       NaN         NaN           M  2020.083333
# 770       NaN     NaN       NaN         NaN           M  2020.166667
# 771       NaN     NaN       NaN         NaN           M  2020.250000
# 772       NaN     NaN       NaN         NaN           M  2020.333333
# 773       NaN     NaN       NaN         NaN           M  2020.416667
#
#        Value.1  Unnamed: 7 FREQUENCY.2   TIME_Q   Value.2
# 0     49.21284         NaN           Q  1956.50  49.05808
# ...

# %%
time1 = ipi.loc[:,'TIME_Y']
time2 = ipi.loc[:,'TIME_M']
time3 = ipi.loc[:,'TIME_Q']
print(time1[0:12])
print(time2[0:12])
print(time3[0:12])
# Out:
# 0     1955.0
# 1     1956.0
# 2     1957.0
# 3     1958.0
# 4     1959.0
# 5     1960.0
# 6     1961.0
# 7     1962.0
# 8     1963.0
# 9     1964.0
# 10    1965.0
# 11    1966.0
# Name: TIME_Y, dtype: float64
# 0     1956.000000
# 1     1956.083333
# 2     1956.166667
# 3     1956.250000
# 4     1956.333333
# 5     1956.416667
# 6     1956.500000
# 7     1956.583333
# 8     1956.666667
# 9     1956.750000
# 10    1956.833333
# 11    1956.916667
# Name: TIME_M, dtype: float64
# 0     1956.50
# 1     1956.75
# 2     1957.00
# 3     1957.25
# 4     1957.50
# 5     1957.75
# 6     1958.00
# 7     1958.25
# 8     1958.50
# 9     1958.75
# 10    1959.00
# 11    1959.25
# Name: TIME_Q, dtype: float64

# %%
value = ipi.loc[:,'Value']
value2 = ipi.loc[:,'Value.1']
value3 = ipi.loc[:,'Value.2']
print(value[0:12])

print(value2[0:12])

print(value3[0:12])
# Out:
# 0     50.97925
# 1     50.89896
# 2     51.94263
# 3     51.17995
# 4     54.20419
# 5     58.02683
# 6     58.32748
# 7     58.88585
# 8     61.16225
# 9     65.54326
# 10    67.51900
# 11    68.33508
# Name: Value, dtype: float64
# 0     49.21284
# 1     49.21284
# 2     48.74857
# 3     49.21284
# 4     48.28429
# 5     49.21284
# 6     48.74857
# 7     48.28429
# 8     49.21284
# 9     48.74857
# 10    49.21284
# 11    48.74857
# Name: Value.1, dtype: float64
# 0     49.05808
# 1     48.90332
# 2     48.74857
# 3     48.90332
# 4     49.52235
# 5     49.98663
# 6     50.60566
# 7     49.83187
# 8     50.50506
# 9     49.51152
# 10    49.18034
# 11    49.67711
# Name: Value.2, dtype: float64

# %%
plt.figure(1)
plt.plot(time3,value3)
plt.legend(['YEAR_FREQUENCY','Production'])
plt.xlabel('Time_Quarters')
plt.ylabel('Production')
plt.savefig('myplot.png')

# %%
plt.figure(2)

plt.plot(time1,value2)
plt.legend(['YEAR_FREQUENCY','Production'])
plt.xlabel('Time_Years')
plt.ylabel('Production')
plt.savefig('myplot.png')

# %% [markdown]
# Both graphs above exhibit a clear reduction in production accross the economy. Looking at the monthly data, there is a close relationship between the economic crash of 2007-2009 to the present ongoing crash. The first graph (quarterly) suggests an even greater hit on the production market. However, considerding this, the general rise in the stock market is concerning as a rise in currency is not an appropriate reflection of the decrease in production since the two contradict eachother.
